# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Reading KHeap performance

# %%
with open('kheap/heap5.txt', 'r') as f:
    lines = f.readlines()

    h5x = [i for i in range(len(lines))]
    h5y = [(float)(line.split()[1]) for line in lines]

# %%
with open('kheap/heap10.txt', 'r') as f:
    lines = f.readlines()

    h10x = [i for i in range(len(lines))]
    h10y = [(float)(line.split()[1]) for line in lines]

# %%
with open('kheap/heap25.txt', 'r') as f:
    lines = f.readlines()

    h25x = [i for i in range(len(lines))]
    h25y = [(float)(line.split()[1]) for line in lines]

# %%
with open('kheap/heap50.txt', 'r') as f:
    lines = f.readlines()

    h50x = [i for i in range(len(lines))]
    h50y = [(float)(line.split()[1]) for line in lines]

# %%
with open('kheap/heap100.txt', 'r') as f:
    lines = f.readlines()

    h100x = [i for i in range(len(lines))]
    h100y = [(float)(line.split()[1]) for line in lines]

# %%
with open('kheap/heap200.txt', 'r') as f:
    lines = f.readlines()

    h200x = [i for i in range(len(lines))]
    h200y = [(float)(line.split()[1]) for line in lines]

# %%
with open('kheap/heap300.txt', 'r') as f:
    lines = f.readlines()

    h300x = [i for i in range(len(lines))]
    h300y = [(float)(line.split()[1]) for line in lines]

# %%
with open('kheap/heap400.txt', 'r') as f:
    lines = f.readlines()

    h400x = [i for i in range(len(lines))]
    h400y = [(float)(line.split()[1]) for line in lines]

# %%
with open('kheap/heap500.txt', 'r') as f:
    lines = f.readlines()

    h500x = [i for i in range(len(lines))]
    h500y = [(float)(line.split()[1]) for line in lines]

# %%
with open('kheap/heap1000.txt', 'r') as f:
    lines = f.readlines()

    h1000x = [i for i in range(len(lines))]
    h1000y = [(float)(line.split()[1]) for line in lines]

# %% [markdown]
# Read binheap performance

# %%
with open('binheap.txt', 'r') as f:
    lines = f.readlines()

    binx = [i for i in range(len(lines))]
    biny = [(float)(line.split()[1]) for line in lines]

# %% [markdown]
# Drawing graphs

# %%
plt.xlabel('Element count', color = 'gray')
plt.ylabel('Time (ms)', color = 'gray')

plt.title('All heaps comparison', fontsize = 15)

plt.plot(binx, biny)
plt.plot(h5x, h5y)
plt.plot(h10x, h10y)
plt.plot(h25x, h25y)
plt.plot(h50x, h50y)
plt.plot(h100x, h100y)
plt.plot(h200x, h200y)
plt.plot(h300x, h300y)
plt.plot(h400x, h400y)
plt.plot(h500x, h500y)
plt.plot(h1000x, h1000y)

plt.legend(['k = 2', 'k = 5', 
            'k = 10', 'k = 25',
            'k = 50', 'k = 100',
            'k = 200', 'k = 300', 
            'k = 400', 'k = 500', 
            'k = 1000'])

plt.xticks([])  # removing numbers on x
plt.show()
